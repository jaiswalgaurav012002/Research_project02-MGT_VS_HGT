# %%
import requests
import json
import csv
import time
import logging
from tqdm import tqdm
import pandas as pd
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

def search_wikipedia_topics(search_term, min_words, max_words, headers, max_articles):
    base_url = "https://hi.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "list": "search",
        "srsearch": search_term,
        "srnamespace": "0",
        "srlimit": "1000",  # Maximum limit per query
        "format": "json"
    }
    
    articles = []
    sroffset = 0  # Offset for pagination
    
    session = requests_retry_session()
    
    while len(articles) < max_articles:
        params['sroffset'] = sroffset
        try:
            response = session.get(base_url, params=params, headers=headers)
            response.raise_for_status()
            data = response.json()
            
            results = data.get('query', {}).get('search', [])
            if not results:
                break  # No more results to fetch
            
            for result in tqdm(results, desc=f"Searching articles for {search_term}"):
                title = result['title']
                article = fetch_wikipedia_article(title, min_words, max_words, headers, search_term)
                if article:
                    articles.append(article)
                
                time.sleep(0.2)  # Delay to respect rate limits
                
                if len(articles) >= max_articles:
                    break
            
            sroffset += len(results)  # Move to the next batch of results
            
        except requests.exceptions.RequestException as e:
            logging.error(f"Error searching for topics with term {search_term}: {e}")
            break

    return articles

def fetch_wikipedia_article(title, min_words, max_words, headers, search_term):
    base_url = "https://hi.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "titles": title,
        "prop": "extracts",
        # Changed to False to fetch full text
        "exintro": "false",
        "explaintext": "",
        "format": "json"
    }
    
    try:
        response = requests.get(base_url, params=params, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        for page in data['query']['pages'].values():
            if 'extract' in page:
                content = page['extract']
                words = len(content.split())
                if min_words <= words <= max_words:
                    logging.info(f"Successfully fetched article: {title} with {words} words")
                    return {
                        'title': page['title'],
                        'content': content,
                        'word_count': words,
                        'topic': search_term.split()[0]  # Adjust if Hindi topics have spaces
                    }
                else:
                    if words < min_words:
                        logging.info(f"Article '{title}' was below word count limit with {words} words")
                    else:
                        logging.info(f"Article '{title}' exceeded word count limit with {words} words")
            else:
                logging.warning(f"No extract found for {title}")
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching {title}: {e}")
    return None

def main():
    articles = []
    max_articles = 3000
    min_words = 300
    max_words = 450
    
    headers = {
        'User-Agent': 'MultiTopicArticlesFetcher/1.0 (yourname@example.com)'
    }
    
    # List of new topics in Hindi, expanded for testing
    topics = [
        "कृषि"
    ]
    
    for topic in topics:
        if len(articles) < max_articles:
            articles.extend(search_wikipedia_topics(topic, min_words, max_words, headers, max_articles - len(articles)))
        if len(articles) >= max_articles:
            break
    
    # Save to CSV
    csv_file = 'multi_topic_articles_300_to_450_1.csv'
    with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['title', 'content', 'word_count', 'topic']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for article in articles[:max_articles]:
            writer.writerow(article)
    
    # Convert CSV to Excel
    df = pd.read_csv(csv_file, encoding='utf-8')
    df.to_excel('multi_topic_articles_300_to_450_1.xlsx', index=False)
    logging.info("CSV file has been converted to Excel format.")

if __name__ == "__main__":
    main()
# Out:
# Searching articles for कृषि:   0%|          | 0/500 [00:00<?, ?it/s]2025-02-02 21:17:22,706 - INFO - Article 'कृषि' exceeded word count limit with 516 words
# Searching articles for कृषि:   0%|          | 1/500 [00:00<07:54,  1.05it/s]2025-02-02 21:17:23,573 - INFO - Article 'गोविन्द बल्लभ पन्त कृषि एवं प्रौद्योगिकी विश्वविद्यालय' was below word count limit with 87 words
# Searching articles for कृषि:   0%|          | 2/500 [00:01<07:29,  1.11it/s]2025-02-02 21:17:24,286 - INFO - Article 'भारत में कृषि' was below word count limit with 139 words
# Searching articles for कृषि:   1%|          | 3/500 [00:02<06:43,  1.23it/s]2025-02-02 21:17:25,147 - INFO - Article 'गहन कृषि' was below word count limit with 118 words
# Searching articles for कृषि:   1%|          | 4/500 [00:03<06:54,  1.20it/s]2025-02-02 21:17:25,957 - INFO - Article 'कृषि इंजीनियरी' was below word count limit with 29 words
# Searching articles for कृषि:   1%|          | 5/500 [00:04<06:48,  1.21it/s]2025-02-02 21:17:26,701 - INFO - Successfully fetched article: कृषि विज्ञान with 411 words
# Searching articles for कृषि:   1%|          | 6/500 [00:04<06:34,  1.25it/s]2025-02-02 21:17:27,562 - INFO - Article 'स्थाई कृषि' was below word count limit with 145 words
# Searching articles for कृषि:   1%|▏         | 7/500 [00:05<06:42,  1.23it/s]2025-02-02 21:17:28,304 - INFO - Article 'भारतीय कृषि अनुसंधान परिषद' was below word count limit with 66 words
# Searching articles for कृषि:   2%|▏         | 8/500 [00:06<06:29,  1.26it/s]2025-02-02 21:17:29,019 - INFO - Article 'चन्द्र शेखर आजाद कृषि एवं प्रौद्योगिकी विश्वविद्यालय' was below word count limit with 79 words
# Searching articles for कृषि:   2%|▏         | 9/500 [00:07<06:17,  1.30it/s]2025-02-02 21:17:29,793 - INFO - Article 'बिधान चन्द्र कृषि विश्वविद्यालय' was below word count limit with 39 words
# Searching articles for कृषि:   2%|▏         | 10/500 [00:08<06:18,  1.29it/s]2025-02-02 21:17:30,579 - INFO - Article 'कृषि अर्थशास्त्र' was below word count limit with 234 words
# Searching articles for कृषि:   2%|▏         | 11/500 [00:08<06:20,  1.29it/s]2025-02-02 21:17:31,396 - INFO - Article 'भारतीय कृषि अनुसंधान संस्थान' was below word count limit with 155 words
# Searching articles for कृषि:   2%|▏         | 12/500 [00:09<06:24,  1.27it/s]2025-02-02 21:17:32,271 - INFO - Article 'कृषि मंत्रालय, भारत सरकार' was below word count limit with 94 words
# Searching articles for कृषि:   3%|▎         | 13/500 [00:10<06:40,  1.22it/s]2025-02-02 21:17:33,412 - INFO - Successfully fetched article: ब्रिटेन की कृषि क्रांति with 330 words
# Searching articles for कृषि:   3%|▎         | 14/500 [00:11<07:22,  1.10it/s]2025-02-02 21:17:34,161 - INFO - Article 'जीविका कृषि' was below word count limit with 61 words
# Searching articles for कृषि:  16%|█▌        | 79/500 [01:02<05:25,  1.29it/s]2025-02-02 21:18:24,874 - INFO - Article 'कृषि प्रोद्योगिकी प्रबंध अभिकरण' was below word count limit with 130 words
# Searching articles for कृषि:  16%|█▌        | 80/500 [01:03<05:28,  1.28it/s]2025-02-02 21:18:25,669 - INFO - Article 'उत्तर बंगाल कृषि' was below word count limit with 9 words
# Searching articles for कृषि:  16%|█▌        | 81/500 [01:03<05:29,  1.27it/s]2025-02-02 21:18:26,419 - INFO - Article 'कृषि महाविद्यालय, आजमगढ़' was below word count limit with 35 words
# Searching articles for कृषि:  16%|█▋        | 82/500 [01:04<05:23,  1.29it/s]2025-02-02 21:18:27,174 - INFO - Article 'महाराणा प्रताप कृषि एवं प्रौद्योगिकी विश्वविद्यालय' was below word count limit with 48 words
# Searching articles for कृषि:  17%|█▋        | 83/500 [01:05<05:21,  1.30it/s]2025-02-02 21:18:27,971 - INFO - Article 'वन्यजीव कृषि' was below word count limit with 35 words
# Searching articles for कृषि:  17%|█▋        | 84/500 [01:06<05:23,  1.29it/s]2025-02-02 21:18:28,782 - INFO - Article 'कृषि की उत्तम पद्धतियाँ' was below word count limit with 22 words
# Searching articles for कृषि:  17%|█▋        | 85/500 [01:07<05:26,  1.27it/s]2025-02-02 21:18:29,539 - INFO - Article 'भारतीय कृषि में महिलाएं' was below word count limit with 156 words
# Searching articles for कृषि:  17%|█▋        | 86/500 [01:07<05:22,  1.29it/s]2025-02-02 21:18:31,363 - INFO - Article 'अंतर्राष्ट्रीय कृषि विकास कोष' was below word count limit with 84 words
# Searching articles for कृषि:  17%|█▋        | 87/500 [01:09<07:31,  1.09s/it]2025-02-02 21:18:32,159 - INFO - Article 'केन्द्रीय बारानी कृषि अनुसन्धान संस्थान' was below word count limit with 44 words
# Searching articles for कृषि:  18%|█▊        | 88/500 [01:10<06:53,  1.00s/it]2025-02-02 21:18:32,941 - INFO - Article 'विस्तृत कृषि' was below word count limit with 45 words
# Searching articles for कृषि:  18%|█▊        | 89/500 [01:11<06:24,  1.07it/s]2025-02-02 21:18:33,783 - INFO - Article 'कृषि महाविद्यालय, लखीमपुर-खीरी' was below word count limit with 51 words
# Searching articles for कृषि:  18%|█▊        | 90/500 [01:12<06:13,  1.10it/s]2025-02-02 21:18:34,543 - INFO - Article 'भारतीय कृषि सांख्यिकी अनुसंधान संस्थान' was below word count limit with 78 words
# Searching articles for कृषि:  18%|█▊        | 90/500 [01:12<05:31,  1.24it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 153
#     150     logging.info("CSV file has been converted to Excel format.")
#     152 if __name__ == "__main__":
# --> 153     main()
#
# Cell In[4], line 134, in main()
#     132 for topic in topics:
#     133     if len(articles) < max_articles:
# --> 134         articles.extend(search_wikipedia_topics(topic, min_words, max_words, headers, max_articles - len(articles)))
#     135     if len(articles) >= max_articles:
#     136         break
#
# Cell In[4], line 64, in search_wikipedia_topics(search_term, min_words, max_words, headers, max_articles)
#      61 if article:
#      62     articles.append(article)
# ---> 64 time.sleep(0.2)  # Delay to respect rate limits
#      66 if len(articles) >= max_articles:
#      67     break
#
# KeyboardInterrupt:
