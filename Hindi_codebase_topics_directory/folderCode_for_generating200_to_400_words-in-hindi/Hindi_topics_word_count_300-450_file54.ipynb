# %%
import requests
import json
import csv
import time
import logging
from tqdm import tqdm
import pandas as pd
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

def search_wikipedia_topics(search_term, max_words, headers, max_articles):
    base_url = "https://hi.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "list": "search",
        "srsearch": search_term,
        "srnamespace": "0",
        "srlimit": "1000",  # Maximum limit per query
        "format": "json"
    }
    
    articles = []
    sroffset = 0  # Offset for pagination
    
    session = requests_retry_session()
    
    while len(articles) < max_articles:
        params['sroffset'] = sroffset
        try:
            response = session.get(base_url, params=params, headers=headers)
            response.raise_for_status()
            data = response.json()
            
            results = data.get('query', {}).get('search', [])
            if not results:
                break  # No more results to fetch
            
            for result in tqdm(results, desc=f"Searching articles for {search_term}"):
                title = result['title']
                article = fetch_wikipedia_article(title, max_words, headers, search_term)
                if article:
                    articles.append(article)
                
                time.sleep(0.5)  # Increased delay to respect rate limits
                
                if len(articles) >= max_articles:
                    break
            
            sroffset += len(results)  # Move to the next batch of results
            
        except requests.exceptions.RequestException as e:
            logging.error(f"Error searching for topics with term {search_term}: {e}")
            break

    return articles

def fetch_wikipedia_article(title, max_words, headers, search_term):
    base_url = "https://hi.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "titles": title,
        "prop": "extracts",
        "exintro": "",
        "explaintext": "",
        "format": "json"
    }
    
    try:
        response = requests.get(base_url, params=params, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        for page in data['query']['pages'].values():
            if 'extract' in page:
                content = page['extract']
                words = len(content.split())
                if words <= max_words:
                    logging.info(f"Successfully fetched article: {title}")
                    return {
                        'title': page['title'],
                        'content': content,
                        'word_count': words,
                        'topic': search_term.split()[0]  # Adjust if Hindi topics have spaces
                    }
                else:
                    logging.info(f"Article '{title}' exceeded word count limit")
            else:
                logging.warning(f"No extract found for {title}")
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching {title}: {e}")
    return None

def main():
    articles = []
    max_articles = 3000
    min_words = 301
    max_words = 450
    
    headers = {
        'User-Agent': 'MultiTopicArticlesFetcher/1.0 (yourname@example.com)'
    }
    
    # List of new topics in Hindi
    topics = [
           "स्वास्थ्य और फिटनेस"
    ]
    
    for topic in topics:
        if len(articles) < max_articles:
            articles.extend(search_wikipedia_topics(topic, max_words, headers, max_articles - len(articles)))
        if len(articles) >= max_articles:
            break
    
    # Save to CSV
    csv_file = 'multi_topic_articles_300_to_450_54.csv'
    with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['title', 'content', 'word_count', 'topic']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for article in articles[:max_articles]:
            writer.writerow(article)
            
    
    # Convert CSV to Excel
    df = pd.read_csv(csv_file, encoding='utf-8')
    df.to_excel('multi_topic_articles_300_to_450_54.xlsx', index=False)
    logging.info("CSV file has been converted to Excel format.")

if __name__ == "__main__":
    main()
# Out:
# Searching articles for स्वास्थ्य और फिटनेस:   0%|          | 0/73 [00:00<?, ?it/s]2025-02-02 16:57:24,095 - INFO - Successfully fetched article: शारीरिक स्वस्थता
# Searching articles for स्वास्थ्य और फिटनेस:   1%|▏         | 1/73 [00:01<01:21,  1.14s/it]2025-02-02 16:57:25,468 - INFO - Successfully fetched article: ईरान में स्वास्थ्य
# Searching articles for स्वास्थ्य और फिटनेस:   3%|▎         | 2/73 [00:02<01:30,  1.28s/it]2025-02-02 16:57:26,520 - INFO - Successfully fetched article: कोनामी होल्डिंग्स
# Searching articles for स्वास्थ्य और फिटनेस:   4%|▍         | 3/73 [00:03<01:22,  1.17s/it]2025-02-02 16:57:27,509 - INFO - Successfully fetched article: वस्तु अंतरजाल
# Searching articles for स्वास्थ्य और फिटनेस:   5%|▌         | 4/73 [00:04<01:15,  1.10s/it]2025-02-02 16:57:28,560 - INFO - Successfully fetched article: शारीरिक
# Searching articles for स्वास्थ्य और फिटनेस:   7%|▋         | 5/73 [00:05<01:13,  1.08s/it]2025-02-02 16:57:29,596 - INFO - Successfully fetched article: जिप्सी बूट्स
# Searching articles for स्वास्थ्य और फिटनेस:   8%|▊         | 6/73 [00:06<01:11,  1.07s/it]2025-02-02 16:57:30,605 - INFO - Successfully fetched article: च्यासाल
# Searching articles for स्वास्थ्य और फिटनेस:  10%|▉         | 7/73 [00:07<01:09,  1.05s/it]2025-02-02 16:57:31,612 - INFO - Successfully fetched article: लक्ष्मीबाई राष्ट्रीय शारीरिक शिक्षा विश्वविद्यालय, ग्‍वालियर
# Searching articles for स्वास्थ्य और फिटनेस:  11%|█         | 8/73 [00:08<01:07,  1.03s/it]2025-02-02 16:57:32,688 - INFO - Successfully fetched article: राष्ट्रीय रचनाकार पुरस्कार
# Searching articles for स्वास्थ्य और फिटनेस:  12%|█▏        | 9/73 [00:09<01:07,  1.05s/it]2025-02-02 16:57:33,661 - INFO - Successfully fetched article: जेनेटिक एल्गोरिद्म
# Searching articles for स्वास्थ्य और फिटनेस:  14%|█▎        | 10/73 [00:10<01:04,  1.02s/it]2025-02-02 16:57:34,642 - INFO - Successfully fetched article: जॉगिंग
# Searching articles for स्वास्थ्य और फिटनेस:  15%|█▌        | 11/73 [00:11<01:02,  1.01s/it]2025-02-02 16:57:35,665 - INFO - Successfully fetched article: फालुन गोंग
# Searching articles for स्वास्थ्य और फिटनेस:  16%|█▋        | 12/73 [00:12<01:01,  1.02s/it]2025-02-02 16:57:36,648 - INFO - Successfully fetched article: बरगद
# Searching articles for स्वास्थ्य और फिटनेस:  18%|█▊        | 13/73 [00:13<01:00,  1.00s/it]2025-02-02 16:57:37,651 - INFO - Successfully fetched article: संजय गुप्ता
# Searching articles for स्वास्थ्य और फिटनेस:  62%|██████▏   | 45/73 [00:47<00:28,  1.02s/it]2025-02-02 16:58:11,272 - INFO - Successfully fetched article: सहज वृत्ति (इंस्टिंक्ट)
# Searching articles for स्वास्थ्य और फिटनेस:  63%|██████▎   | 46/73 [00:48<00:27,  1.01s/it]2025-02-02 16:58:12,262 - INFO - Successfully fetched article: अर्नोल्ड श्वार्ज़नेगर
# Searching articles for स्वास्थ्य और फिटनेस:  64%|██████▍   | 47/73 [00:49<00:26,  1.01s/it]2025-02-02 16:58:13,671 - INFO - Successfully fetched article: मानसी जोशी (पैरा-बैडमिन्टन खिलाड़ी)
# Searching articles for स्वास्थ्य और फिटनेस:  66%|██████▌   | 48/73 [00:50<00:28,  1.13s/it]2025-02-02 16:58:14,719 - INFO - Successfully fetched article: तरण ताल
# Searching articles for स्वास्थ्य और फिटनेस:  67%|██████▋   | 49/73 [00:51<00:26,  1.10s/it]2025-02-02 16:58:15,722 - INFO - Successfully fetched article: उत्तरजीविता कौशल
# Searching articles for स्वास्थ्य और फिटनेस:  68%|██████▊   | 50/73 [00:52<00:24,  1.07s/it]2025-02-02 16:58:16,689 - INFO - Successfully fetched article: रिबॉक
# Searching articles for स्वास्थ्य और फिटनेस:  70%|██████▉   | 51/73 [00:53<00:22,  1.04s/it]2025-02-02 16:58:17,680 - INFO - Article 'मार्शल आर्ट' exceeded word count limit
# Searching articles for स्वास्थ्य और फिटनेस:  71%|███████   | 52/73 [00:54<00:21,  1.03s/it]2025-02-02 16:58:18,675 - INFO - Successfully fetched article: कंप्यूटर सुरक्षा
# Searching articles for स्वास्थ्य और फिटनेस:  73%|███████▎  | 53/73 [00:55<00:20,  1.02s/it]2025-02-02 16:58:19,694 - INFO - Successfully fetched article: बृहदांत्र कैन्सर
# Searching articles for स्वास्थ्य और फिटनेस:  74%|███████▍  | 54/73 [00:56<00:19,  1.02s/it]2025-02-02 16:58:20,684 - INFO - Successfully fetched article: स्क्वैश (खेल)
# Searching articles for स्वास्थ्य और फिटनेस:  75%|███████▌  | 55/73 [00:57<00:18,  1.01s/it]2025-02-02 16:58:21,664 - INFO - Successfully fetched article: अल्फाबेट कंपनी
# Searching articles for स्वास्थ्य और फिटनेस:  77%|███████▋  | 56/73 [00:58<00:17,  1.00s/it]2025-02-02 16:58:22,657 - INFO - Successfully fetched article: अंतरराष्ट्रीय अपराध न्यायालय
# Searching articles for स्वास्थ्य और फिटनेस:  78%|███████▊  | 57/73 [00:59<00:15,  1.00it/s]2025-02-02 16:58:23,636 - INFO - Successfully fetched article: मैनचेस्टर यूनाइटेड एफ़.सी.
# Searching articles for स्वास्थ्य और फिटनेस:  79%|███████▉  | 58/73 [01:00<00:14,  1.01it/s]2025-02-02 16:58:24,619 - INFO - Successfully fetched article: डेवी दशमलव वर्ग सूची
# Searching articles for स्वास्थ्य और फिटनेस:  81%|████████  | 59/73 [01:01<00:13,  1.01it/s]2025-02-02 16:58:26,642 - INFO - Article 'इंटेल' exceeded word count limit
# Searching articles for स्वास्थ्य और फिटनेस:  82%|████████▏ | 60/73 [01:03<00:16,  1.30s/it]2025-02-02 16:58:27,660 - INFO - Successfully fetched article: मिल्वौकी, विस्कॉन्सिन
# Searching articles for स्वास्थ्य और फिटनेस:  84%|████████▎ | 61/73 [01:04<00:14,  1.22s/it]2025-02-02 16:58:28,693 - INFO - Successfully fetched article: भार प्रशिक्षण (वेट ट्रेनिंग)
# Searching articles for स्वास्थ्य और फिटनेस:  85%|████████▍ | 62/73 [01:05<00:12,  1.16s/it]2025-02-02 16:58:29,696 - INFO - Successfully fetched article: एलेक्स फर्ग्यूसन
# Searching articles for स्वास्थ्य और फिटनेस:  86%|████████▋ | 63/73 [01:06<00:11,  1.11s/it]2025-02-02 16:58:30,693 - INFO - Successfully fetched article: शैक्षणिक विषयों की सूची
# Searching articles for स्वास्थ्य और फिटनेस:  88%|████████▊ | 64/73 [01:07<00:09,  1.08s/it]2025-02-02 16:58:31,762 - INFO - Successfully fetched article: डेविड बेखम
# Searching articles for स्वास्थ्य और फिटनेस:  89%|████████▉ | 65/73 [01:08<00:08,  1.08s/it]2025-02-02 16:58:32,769 - INFO - Successfully fetched article: इंडियन स्कूल ऑफ़ बिज़नेस
# Searching articles for स्वास्थ्य और फिटनेस:  90%|█████████ | 66/73 [01:09<00:07,  1.05s/it]2025-02-02 16:58:33,785 - INFO - Successfully fetched article: सिकल-सेल रोग
# Searching articles for स्वास्थ्य और फिटनेस:  92%|█████████▏| 67/73 [01:10<00:06,  1.04s/it]2025-02-02 16:58:34,793 - INFO - Successfully fetched article: ऐनबालिक स्टेरॉयड
# Searching articles for स्वास्थ्य और फिटनेस:  93%|█████████▎| 68/73 [01:11<00:05,  1.03s/it]2025-02-02 16:58:35,813 - INFO - Successfully fetched article: हीडलबर्ग विश्वविद्यालय
# Searching articles for स्वास्थ्य और फिटनेस:  95%|█████████▍| 69/73 [01:12<00:04,  1.03s/it]2025-02-02 16:58:36,843 - INFO - Successfully fetched article: ब्रॉक लेसनर
# Searching articles for स्वास्थ्य और फिटनेस:  96%|█████████▌| 70/73 [01:13<00:03,  1.03s/it]2025-02-02 16:58:37,843 - INFO - Successfully fetched article: फोर सीजन्स होटल मुंबई
# Searching articles for स्वास्थ्य और फिटनेस:  97%|█████████▋| 71/73 [01:14<00:02,  1.02s/it]2025-02-02 16:58:38,844 - INFO - Successfully fetched article: न्यूकैसल युनाइटेड एफ़॰सी॰
# Searching articles for स्वास्थ्य और फिटनेस:  99%|█████████▊| 72/73 [01:15<00:01,  1.02s/it]2025-02-02 16:58:39,908 - INFO - Successfully fetched article: रोचेस्टर, न्यूयॉर्क
# Searching articles for स्वास्थ्य और फिटनेस: 100%|██████████| 73/73 [01:16<00:00,  1.05s/it]
# 2025-02-02 16:58:42,985 - INFO - CSV file has been converted to Excel format.
