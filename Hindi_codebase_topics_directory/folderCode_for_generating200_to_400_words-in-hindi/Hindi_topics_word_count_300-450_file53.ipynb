# %%
import requests
import json
import csv
import time
import logging
from tqdm import tqdm
import pandas as pd
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

def search_wikipedia_topics(search_term, max_words, headers, max_articles):
    base_url = "https://hi.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "list": "search",
        "srsearch": search_term,
        "srnamespace": "0",
        "srlimit": "1000",  # Maximum limit per query
        "format": "json"
    }
    
    articles = []
    sroffset = 0  # Offset for pagination
    
    session = requests_retry_session()
    
    while len(articles) < max_articles:
        params['sroffset'] = sroffset
        try:
            response = session.get(base_url, params=params, headers=headers)
            response.raise_for_status()
            data = response.json()
            
            results = data.get('query', {}).get('search', [])
            if not results:
                break  # No more results to fetch
            
            for result in tqdm(results, desc=f"Searching articles for {search_term}"):
                title = result['title']
                article = fetch_wikipedia_article(title, max_words, headers, search_term)
                if article:
                    articles.append(article)
                
                time.sleep(0.5)  # Increased delay to respect rate limits
                
                if len(articles) >= max_articles:
                    break
            
            sroffset += len(results)  # Move to the next batch of results
            
        except requests.exceptions.RequestException as e:
            logging.error(f"Error searching for topics with term {search_term}: {e}")
            break

    return articles

def fetch_wikipedia_article(title, max_words, headers, search_term):
    base_url = "https://hi.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "titles": title,
        "prop": "extracts",
        "exintro": "",
        "explaintext": "",
        "format": "json"
    }
    
    try:
        response = requests.get(base_url, params=params, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        for page in data['query']['pages'].values():
            if 'extract' in page:
                content = page['extract']
                words = len(content.split())
                if words <= max_words:
                    logging.info(f"Successfully fetched article: {title}")
                    return {
                        'title': page['title'],
                        'content': content,
                        'word_count': words,
                        'topic': search_term.split()[0]  # Adjust if Hindi topics have spaces
                    }
                else:
                    logging.info(f"Article '{title}' exceeded word count limit")
            else:
                logging.warning(f"No extract found for {title}")
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching {title}: {e}")
    return None

def main():
    articles = []
    max_articles = 3000
    min_words = 301
    max_words = 450
    
    headers = {
        'User-Agent': 'MultiTopicArticlesFetcher/1.0 (yourname@example.com)'
    }
    
    # List of new topics in Hindi
    topics = [
           "व्यवसाय और उद्यमिता"
    ]
    
    for topic in topics:
        if len(articles) < max_articles:
            articles.extend(search_wikipedia_topics(topic, max_words, headers, max_articles - len(articles)))
        if len(articles) >= max_articles:
            break
    
    # Save to CSV
    csv_file = 'multi_topic_articles_300_to_450_53.csv'
    with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['title', 'content', 'word_count', 'topic']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for article in articles[:max_articles]:
            writer.writerow(article)
            
    
    # Convert CSV to Excel
    df = pd.read_csv(csv_file, encoding='utf-8')
    df.to_excel('multi_topic_articles_300_to_450_53.xlsx', index=False)
    logging.info("CSV file has been converted to Excel format.")

if __name__ == "__main__":
    main()
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_30144\877728255.py:7: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Searching articles for व्यवसाय और उद्यमिता:   0%|          | 0/69 [00:00<?, ?it/s]2025-02-02 16:56:43,774 - INFO - Successfully fetched article: उद्यमिता
# Searching articles for व्यवसाय और उद्यमिता:   1%|▏         | 1/69 [00:01<01:09,  1.02s/it]2025-02-02 16:56:44,865 - INFO - Successfully fetched article: राष्ट्रीय उद्यमिता लघु व्यवसाय विकास संस्थान
# Searching articles for व्यवसाय और उद्यमिता:   3%|▎         | 2/69 [00:02<01:11,  1.07s/it]2025-02-02 16:56:45,867 - INFO - Successfully fetched article: व्यवसाय
# Searching articles for व्यवसाय और उद्यमिता:   4%|▍         | 3/69 [00:03<01:08,  1.04s/it]2025-02-02 16:56:47,080 - INFO - Article 'व्यवसाय प्रबंध में स्नातकोत्तर' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:   6%|▌         | 4/69 [00:04<01:11,  1.10s/it]2025-02-02 16:56:48,112 - INFO - Successfully fetched article: भारतीय प्रौद्योगिकी संस्थान कानपुर
# Searching articles for व्यवसाय और उद्यमिता:   7%|▋         | 5/69 [00:05<01:09,  1.08s/it]2025-02-02 16:56:49,338 - INFO - Successfully fetched article: उद्यमी
# Searching articles for व्यवसाय और उद्यमिता:   9%|▊         | 6/69 [00:06<01:11,  1.13s/it]2025-02-02 16:56:50,433 - INFO - Successfully fetched article: स्टैण्ड-अप इंडिया
# Searching articles for व्यवसाय और उद्यमिता:  10%|█         | 7/69 [00:07<01:09,  1.12s/it]2025-02-02 16:56:51,516 - INFO - Successfully fetched article: माजुली जिला
# Searching articles for व्यवसाय और उद्यमिता:  12%|█▏        | 8/69 [00:08<01:07,  1.10s/it]2025-02-02 16:56:52,535 - INFO - Successfully fetched article: वाणी कोला
# Searching articles for व्यवसाय और उद्यमिता:  13%|█▎        | 9/69 [00:09<01:04,  1.08s/it]2025-02-02 16:56:53,564 - INFO - Successfully fetched article: २ जून
# Searching articles for व्यवसाय और उद्यमिता:  14%|█▍        | 10/69 [00:10<01:02,  1.06s/it]2025-02-02 16:56:54,587 - INFO - Successfully fetched article: सिनर्जी विश्वविद्यालय
# Searching articles for व्यवसाय और उद्यमिता:  16%|█▌        | 11/69 [00:11<01:01,  1.05s/it]2025-02-02 16:56:55,636 - INFO - Successfully fetched article: भारतीय प्रौद्योगिकी संस्थान मण्डी
# Searching articles for व्यवसाय और उद्यमिता:  17%|█▋        | 12/69 [00:12<00:59,  1.05s/it]2025-02-02 16:56:56,660 - INFO - Successfully fetched article: व्यापारी
# Searching articles for व्यवसाय और उद्यमिता:  19%|█▉        | 13/69 [00:13<00:58,  1.04s/it]2025-02-02 16:56:57,708 - INFO - Successfully fetched article: आजीविका
# Searching articles for व्यवसाय और उद्यमिता:  20%|██        | 14/69 [00:14<00:57,  1.04s/it]2025-02-02 16:56:58,810 - INFO - Successfully fetched article: लैला इस्कंदर
# Searching articles for व्यवसाय और उद्यमिता:  22%|██▏       | 15/69 [00:16<00:57,  1.06s/it]2025-02-02 16:56:59,860 - INFO - Successfully fetched article: दि कलिनरी इंस्टीट्यूट ऑफ़ अमेरिका
# Searching articles for व्यवसाय और उद्यमिता:  23%|██▎       | 16/69 [00:17<00:55,  1.06s/it]2025-02-02 16:57:00,860 - INFO - Successfully fetched article: रश्मी बंसल
# Searching articles for व्यवसाय और उद्यमिता:  25%|██▍       | 17/69 [00:18<00:54,  1.04s/it]2025-02-02 16:57:01,945 - INFO - Successfully fetched article: कंपनी
# Searching articles for व्यवसाय और उद्यमिता:  26%|██▌       | 18/69 [00:19<00:53,  1.05s/it]2025-02-02 16:57:02,975 - INFO - Successfully fetched article: हार्वर्ड बिजनेस स्कूल
# Searching articles for व्यवसाय और उद्यमिता:  28%|██▊       | 19/69 [00:20<00:52,  1.05s/it]2025-02-02 16:57:04,384 - INFO - Article 'सिडनी' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  29%|██▉       | 20/69 [00:21<00:56,  1.15s/it]2025-02-02 16:57:05,410 - INFO - Successfully fetched article: बीमा
# Searching articles for व्यवसाय और उद्यमिता:  30%|███       | 21/69 [00:22<00:53,  1.12s/it]2025-02-02 16:57:06,473 - INFO - Successfully fetched article: जैन विश्वविद्यालय
# Searching articles for व्यवसाय और उद्यमिता:  32%|███▏      | 22/69 [00:23<00:51,  1.10s/it]2025-02-02 16:57:07,514 - INFO - Successfully fetched article: गुजरात विश्वविद्यालय
# Searching articles for व्यवसाय और उद्यमिता:  33%|███▎      | 23/69 [00:24<00:49,  1.08s/it]2025-02-02 16:57:08,579 - INFO - Article 'भूतंत्र' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  35%|███▍      | 24/69 [00:25<00:48,  1.08s/it]2025-02-02 16:57:09,816 - INFO - Article 'आपुर्ति पक्ष नीति' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  36%|███▌      | 25/69 [00:27<00:49,  1.12s/it]2025-02-02 16:57:11,014 - INFO - Successfully fetched article: प्रबन्धन
# Searching articles for व्यवसाय और उद्यमिता:  38%|███▊      | 26/69 [00:28<00:49,  1.15s/it]2025-02-02 16:57:12,097 - INFO - Successfully fetched article: जन सेवा केंद्र
# Searching articles for व्यवसाय और उद्यमिता:  39%|███▉      | 27/69 [00:29<00:47,  1.13s/it]2025-02-02 16:57:13,250 - INFO - Successfully fetched article: औद्योगिक क्रांति
# Searching articles for व्यवसाय और उद्यमिता:  41%|████      | 28/69 [00:30<00:46,  1.14s/it]2025-02-02 16:57:14,313 - INFO - Successfully fetched article: नंदिनी मुंडकुर
# Searching articles for व्यवसाय और उद्यमिता:  42%|████▏     | 29/69 [00:31<00:44,  1.11s/it]2025-02-02 16:57:15,475 - INFO - Successfully fetched article: निजीकरण
# Searching articles for व्यवसाय और उद्यमिता:  43%|████▎     | 30/69 [00:32<00:43,  1.13s/it]2025-02-02 16:57:16,753 - INFO - Article 'खुदरा प्रबंधन' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  45%|████▍     | 31/69 [00:34<00:44,  1.17s/it]2025-02-02 16:57:17,807 - INFO - Successfully fetched article: वाणिज्यवाद
# Searching articles for व्यवसाय और उद्यमिता:  46%|████▋     | 32/69 [00:35<00:42,  1.14s/it]2025-02-02 16:57:19,092 - INFO - Article 'शाहरुख़ ख़ान' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  48%|████▊     | 33/69 [00:36<00:42,  1.18s/it]2025-02-02 16:57:20,134 - INFO - Successfully fetched article: कोर्स हीरो
# Searching articles for व्यवसाय और उद्यमिता:  49%|████▉     | 34/69 [00:37<00:39,  1.14s/it]2025-02-02 16:57:21,462 - INFO - Article 'स्टार्टअप कंपनी' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  51%|█████     | 35/69 [00:38<00:40,  1.20s/it]2025-02-02 16:57:22,517 - INFO - Successfully fetched article: अनन्या बिड़ला
# Searching articles for व्यवसाय और उद्यमिता:  52%|█████▏    | 36/69 [00:39<00:38,  1.15s/it]2025-02-02 16:57:23,726 - INFO - Article 'राष्ट्रीय नवप्रवर्तन संस्थान' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  54%|█████▎    | 37/69 [00:40<00:37,  1.17s/it]2025-02-02 16:57:25,353 - INFO - Article 'एडम स्मिथ' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  55%|█████▌    | 38/69 [00:42<00:40,  1.31s/it]2025-02-02 16:57:26,421 - INFO - Successfully fetched article: डेविड रिकार्डो
# Searching articles for व्यवसाय और उद्यमिता:  57%|█████▋    | 39/69 [00:43<00:37,  1.24s/it]2025-02-02 16:57:27,549 - INFO - Successfully fetched article: पृथ्वी के चैंपियंस
# Searching articles for व्यवसाय और उद्यमिता:  58%|█████▊    | 40/69 [00:44<00:34,  1.21s/it]2025-02-02 16:57:28,567 - INFO - Successfully fetched article: स्वपन दास गुप्ता
# Searching articles for व्यवसाय और उद्यमिता:  59%|█████▉    | 41/69 [00:45<00:32,  1.15s/it]2025-02-02 16:57:29,669 - INFO - Successfully fetched article: एना ब्रानबीक
# Searching articles for व्यवसाय और उद्यमिता:  61%|██████    | 42/69 [00:46<00:30,  1.13s/it]2025-02-02 16:57:30,693 - INFO - Successfully fetched article: लघु वित्त
# Searching articles for व्यवसाय और उद्यमिता:  62%|██████▏   | 43/69 [00:47<00:28,  1.10s/it]2025-02-02 16:57:31,775 - INFO - Successfully fetched article: जीरो टू वन
# Searching articles for व्यवसाय और उद्यमिता:  64%|██████▍   | 44/69 [00:49<00:27,  1.09s/it]2025-02-02 16:57:32,824 - INFO - Successfully fetched article: क्रेडिट सुइस
# Searching articles for व्यवसाय और उद्यमिता:  65%|██████▌   | 45/69 [00:50<00:25,  1.08s/it]2025-02-02 16:57:33,854 - INFO - Successfully fetched article: निगम
# Searching articles for व्यवसाय और उद्यमिता:  67%|██████▋   | 46/69 [00:51<00:24,  1.07s/it]2025-02-02 16:57:34,910 - INFO - Successfully fetched article: इंडियन स्कूल ऑफ़ बिज़नेस
# Searching articles for व्यवसाय और उद्यमिता:  68%|██████▊   | 47/69 [00:52<00:23,  1.06s/it]2025-02-02 16:57:35,929 - INFO - Successfully fetched article: पर्यावरण प्रौद्योगिकी
# Searching articles for व्यवसाय और उद्यमिता:  70%|██████▉   | 48/69 [00:53<00:22,  1.05s/it]2025-02-02 16:57:37,032 - INFO - Successfully fetched article: वैश्वीकरण
# Searching articles for व्यवसाय और उद्यमिता:  71%|███████   | 49/69 [00:54<00:21,  1.06s/it]2025-02-02 16:57:38,046 - INFO - Successfully fetched article: नागरिक समाज
# Searching articles for व्यवसाय और उद्यमिता:  72%|███████▏  | 50/69 [00:55<00:19,  1.05s/it]2025-02-02 16:57:39,084 - INFO - Successfully fetched article: माजुली द्वीप
# Searching articles for व्यवसाय और उद्यमिता:  74%|███████▍  | 51/69 [00:56<00:18,  1.05s/it]2025-02-02 16:57:40,127 - INFO - Successfully fetched article: मान्यता दत्त
# Searching articles for व्यवसाय और उद्यमिता:  75%|███████▌  | 52/69 [00:57<00:17,  1.05s/it]2025-02-02 16:57:41,125 - INFO - Successfully fetched article: सुजीत कुमार (राजनीतिज्ञ)
# Searching articles for व्यवसाय और उद्यमिता:  77%|███████▋  | 53/69 [00:58<00:16,  1.03s/it]2025-02-02 16:57:42,160 - INFO - Successfully fetched article: जीसस ह्युअर्टा डि सोटो
# Searching articles for व्यवसाय और उद्यमिता:  78%|███████▊  | 54/69 [00:59<00:15,  1.03s/it]2025-02-02 16:57:43,243 - INFO - Successfully fetched article: जैकी चैन
# Searching articles for व्यवसाय और उद्यमिता:  80%|███████▉  | 55/69 [01:00<00:14,  1.05s/it]2025-02-02 16:57:44,266 - INFO - Successfully fetched article: मैसाचुसेट्स प्रौद्योगिकी संस्थान
# Searching articles for व्यवसाय और उद्यमिता:  81%|████████  | 56/69 [01:01<00:13,  1.04s/it]2025-02-02 16:57:45,277 - INFO - Successfully fetched article: पूंजी बाजार
# Searching articles for व्यवसाय और उद्यमिता:  83%|████████▎ | 57/69 [01:02<00:12,  1.03s/it]2025-02-02 16:57:46,346 - INFO - Successfully fetched article: अख्तर हमीद खान
# Searching articles for व्यवसाय और उद्यमिता:  84%|████████▍ | 58/69 [01:03<00:11,  1.05s/it]2025-02-02 16:57:47,385 - INFO - Successfully fetched article: व्यापार चक्र
# Searching articles for व्यवसाय और उद्यमिता:  86%|████████▌ | 59/69 [01:04<00:10,  1.04s/it]2025-02-02 16:57:48,654 - INFO - Article 'जॉन मेनार्ड कीन्स' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  87%|████████▋ | 60/69 [01:05<00:09,  1.11s/it]2025-02-02 16:57:49,671 - INFO - Successfully fetched article: नैगम शासन
# Searching articles for व्यवसाय और उद्यमिता:  88%|████████▊ | 61/69 [01:06<00:08,  1.08s/it]2025-02-02 16:57:50,701 - INFO - Successfully fetched article: मिश्रित अर्थव्यवस्था
# Searching articles for व्यवसाय और उद्यमिता:  90%|████████▉ | 62/69 [01:07<00:07,  1.07s/it]2025-02-02 16:57:51,911 - INFO - Article 'जॉन केरी' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  91%|█████████▏| 63/69 [01:09<00:06,  1.11s/it]2025-02-02 16:57:52,937 - INFO - Successfully fetched article: शेख मोहम्मद बिन राशिद अल मकतूम
# Searching articles for व्यवसाय और उद्यमिता:  93%|█████████▎| 64/69 [01:10<00:05,  1.09s/it]2025-02-02 16:57:53,970 - INFO - Successfully fetched article: बेंगलुरु
# Searching articles for व्यवसाय और उद्यमिता:  94%|█████████▍| 65/69 [01:11<00:04,  1.07s/it]2025-02-02 16:57:55,028 - INFO - Successfully fetched article: शंकर कुमार सान्याल
# Searching articles for व्यवसाय और उद्यमिता:  96%|█████████▌| 66/69 [01:12<00:03,  1.06s/it]2025-02-02 16:57:56,102 - INFO - Successfully fetched article: शैक्षणिक विषयों की सूची
# Searching articles for व्यवसाय और उद्यमिता:  97%|█████████▋| 67/69 [01:13<00:02,  1.07s/it]2025-02-02 16:57:57,299 - INFO - Article 'केंजो फुजिसु' exceeded word count limit
# Searching articles for व्यवसाय और उद्यमिता:  99%|█████████▊| 68/69 [01:14<00:01,  1.11s/it]2025-02-02 16:57:58,322 - INFO - Successfully fetched article: अक्षय रमणलाल देसाई
# Searching articles for व्यवसाय और उद्यमिता: 100%|██████████| 69/69 [01:15<00:00,  1.10s/it]
# 2025-02-02 16:58:00,428 - INFO - CSV file has been converted to Excel format.
